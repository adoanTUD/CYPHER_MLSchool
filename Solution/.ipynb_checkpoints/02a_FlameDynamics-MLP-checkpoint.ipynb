# %% [markdown]
# # Project: Flame Dynamics Identification
#
# In this project, you will have to develop a neural network that can learn the dynamics of a flame.
# More specifically, the flame dynamics represent how the heat release rate of a flame varies when it is subjected to velocity perturbation and has a strong impact on the overall stability of gas turbines or jet engines. Indeed, a coupling mechanism can occur between the velocity flucatuation, heat release fluctuation and the acoustics of the combustor leading to a phenomena called, _thermoacoustic instabilities_.
#
# More specifically, you will need to identify the following relation:
# \begin{equation}
# \dot{Q}'=\mathcal{F}(u')
# \end{equation}
#
# where $\dot{Q}'$ and $u'$ represent the normalized heat release rate oscillation and the normalized velocity perturbation respectively.
#
# To do so, we are providing you with three different sets of time series of $(u'(t),\dot{Q}'(t))$. Each of those time series have been obtained from simulation where the flame was excited with a broadband signal (meaning that there is a large frequency content in the excitation signal).
#
# The tasks for the project are:
# 1. To train different neural networks for each dataset.
# 2. To obtain the frequency response of each trained neural network for excitation amplitudes of 0.5, 1.0 and 1.5. Vaildations data are provided for you to assess the accuracy of your trained neural network.
#
# The frequency response is obtained by exciting the neural network with a harmonic signal (meaning a sine at a specified frequency with a fixed amplitude). Then, the gain (ratio between the resulting heat release rate signal and excitation signal: $\dot{Q}'/u'$) and phase (the delay between the two signals) are computed.
#
# 3. Study the accuracy of the trained neural network depending on the length of the training signal used.

# %% [markdown]
# The remainder of this notebook will provide a guideline solution when using a feedforward neural network to the problem above. The exercise and solution are based on the results presented in the following paper [Tathawadekar et al., _Modeling of the nonlinear flame response of a Bunsen-type flame via multi-layer perceptron_, Proc. Comb. Inst. (38), 6261-6269 (2021)](https://doi.org/10.1016/j.proci.2020.07.115).

# %%
use_colab = True
if use_colab:
    # !git clone -b main https://github.com/adoanTUD/CYPHER_MLSchool.git

    # from google.colab import drive
    # drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load the required libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import os
import h5py
# pandas is a python library dedicated to data manipulation and analysis
import pandas as pd

import tensorflow as tf

# %% [markdown]
# # 1. Read the input data

# %%
# User defined variables, please provide necessary inputs
# files with *_1.csv: associated with normalized excitation amplitude of 0.5
# files with *_2.csv: associated with normalized excitation amplitude of 1.0
# files with *_3.csv: associated with normalized excitation amplitude of 1.5

if use_colab:
    fld = './CYPHER_MLSchool/'
else:
    fld = '../'
    
input_file = fld + "Flame_Data/input_data_1.csv" # location of input file
output_file = fld + "Flame_Data/output_data_1.csv" # location of output file (true labels)
Ts = 0.000001 # sampling time of the data - all the data have a sampling time of 0.000001 [s]

# load dataset
X_ = pd.read_csv(input_file, header=None)
Y_ = pd.read_csv(output_file, header=None)
T_ = np.arange(X_.shape[0], dtype=int)*Ts
X_ = X_[10000:]
Y_ = Y_[10000:]
T_ = T_[10000:] - T_[10000]
m = X_.shape[0] # number of input data points

# %matplotlib inline
plt.figure()
plt.plot(T_,X_)
plt.plot(T_,Y_)
# Out:
# 989999

# %% [markdown]
# We create hereunder an auxiliary function that will create the input/target pairs for us for a given number of element in the past.

# %%
def create_datasetXY(dataset, labels, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(labels[i + look_back -1, 0])
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# Hereunder, we decide on an undersampling rate as we are not interested in the very high frequency response of the flame. In addition, keeping a time-history of ~10 ms is sufficient for this specific flame. Additional details can be found in this paper by [Tathawadekar et al., _Modeling of the nonlinear flame response of a Bunsen-type flame via multi-layer perceptron_, Proc. Comb. Inst. (38), 6261-6269 (2021).](https://doi.org/10.1016/j.proci.2020.07.115).

# %%
# resampling
# The data may be oversampled so you may want to downsample it to make the training easier
# we are interested in the frequency content of 0-500Hz
m_sample = 15 # resampling rate

resampled_X, resampled_t = signal.resample(X_.values, int(m/m_sample), t=T_) # resample the input
resampled_t = (resampled_t/Ts).astype(int)
resampled_Y = Y_.values[resampled_t,:] # resample the output

# create the training dataset
look_back = 700 # lookback parameter: specify the history
X, Y = create_datasetXY(resampled_X, resampled_Y, look_back)
X = X.reshape((-1,look_back))
Y = Y.reshape((-1,1))

# split the dataset into training and testing data
split = 0.7
train_samples = int(split*X.shape[0])

X_train = X[0:train_samples,:]
Y_train = Y[0:train_samples,:]

X_test = X[train_samples:m,:]
Y_test = Y[train_samples:m,:]

# %% [markdown]
# # 2 Design of the neural network
#
# The network proposed below is based on the paper by [Tathawadekar et al., _Modeling of the nonlinear flame response of a Bunsen-type flame via multi-layer perceptron_, Proc. Comb. Inst. (38), 6261-6269 (2021)](https://doi.org/10.1016/j.proci.2020.07.115).
#
# You can play around and try different architectures and assess the results.

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(73, activation='tanh', input_shape=[look_back]))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(36, activation='tanh'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(1, activation='linear'))

model.compile(loss='mse',optimizer='adam')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
checkpoint_filepath = fld + './checkpoint_MLP.weights.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)
early_stop_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

EPOCHS = 10 # number of epochs for training the model - Use here a much larger value to ensure that you are fully training your network
BATCH_SIZE = 1000
model.fit(X_train, Y_train, batch_size = BATCH_SIZE,
  epochs=EPOCHS, validation_split = 0.2, shuffle = False, verbose=1)
# Out:
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.4544 - val_loss: 0.0030
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0885 - val_loss: 0.0013
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0241 - val_loss: 0.0013
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0097 - val_loss: 0.0012
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0067 - val_loss: 0.0012
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0054 - val_loss: 0.0011
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0049 - val_loss: 0.0010
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0045 - val_loss: 0.0019
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0046 - val_loss: 0.0018
# Epoch 17/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 18/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 19/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 20/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 21/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 22/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 23/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 24/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 25/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 26/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 27/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 28/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 29/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 30/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 31/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 32/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 33/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 34/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 35/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 36/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 37/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 38/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 39/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 40/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 41/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 42/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 43/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 44/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 45/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 46/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 47/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 48/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 49/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 50/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 51/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 52/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 53/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 54/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 55/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 56/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 57/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 58/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 59/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 60/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0026 - val_loss: 9.9619e-04
# Epoch 61/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 62/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 63/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 64/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024 - val_loss: 0.0010
# Epoch 65/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0024 - val_loss: 9.6144e-04
# Epoch 66/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 67/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0023 - val_loss: 9.6038e-04
# Epoch 68/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 69/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0023 - val_loss: 0.0010
# Epoch 70/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 71/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 72/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 73/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 74/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 75/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 76/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 77/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 78/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 79/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 80/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 81/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 82/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 83/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 84/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 85/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 86/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 87/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 88/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0019 - val_loss: 9.7610e-04
# Epoch 89/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0019 - val_loss: 9.7372e-04
# Epoch 90/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0019 - val_loss: 9.3573e-04
# Epoch 91/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0019 - val_loss: 9.7896e-04
# Epoch 92/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - val_loss: 9.8188e-04
# Epoch 93/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - val_loss: 9.0067e-04
# Epoch 94/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0019 - val_loss: 8.8592e-04
# Epoch 95/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - val_loss: 8.6209e-04
# Epoch 96/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018 - val_loss: 8.5933e-04
# Epoch 97/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018 - val_loss: 8.4298e-04
# Epoch 98/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - val_loss: 8.4612e-04
# Epoch 99/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - val_loss: 8.1622e-04
# Epoch 100/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0018 - val_loss: 7.9297e-04

# %% [markdown]
# We assess now the performance of our trained network on the training dataset.

# %%
train_predictions = model.predict(X_train)
plt.figure()
plt.xlabel('Index')
plt.ylabel('Amplitude')
plt.plot(Y_train.flatten(), label='Train True Labels')
plt.plot(train_predictions.flatten(), label = 'Train Predictions')
plt.legend()
# Out:
# 1429/1429 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# We assess the trained network on the testing dataset (the part of our dataset not used during training).

# %%
test_predictions = model.predict(X_test)
# %matplotlib inline
plt.figure()
plt.xlabel('Index')
plt.ylabel('Amplitude')
plt.plot(Y_test.flatten(), label='Test True Labels')
plt.plot(test_predictions.flatten(), label = 'Test Predictions')
plt.legend()
# Out:
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# # 3. Validation data
# As explained, the validation is going to be performed by comparing the frequency response of the neural network and the one from CFD.
# The data from the CFD is provided and we show in the code hereunder how to plot it.

# %%
fln = fld + './Validation_data/Flame_valid_data.h5'
hf = h5py.File(fln,'r')
list(hf.keys())
FDF_freq = np.array(hf.get('f'))
FDF_Gain = np.array(hf.get('Gain'))
FDF_phase = np.array(hf.get('phase'))

# %% [markdown]
# Each line of those arrays corresponds to excitation amplitude of respectively 0.5, 1.0 and 1.5.

# %%
# %matplotlib inline
fig = plt.figure()
ax = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

for i in range(3):
    ax.plot(FDF_freq[i,:],FDF_Gain[i,:],'x')
    ax2.plot(FDF_freq[i,:],FDF_phase[i,:],'x')

ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel('Gain [-]')
ax2.set_xlabel('Frequency [Hz]')
ax2.set_ylabel('Phase delay [rad]')
# Out:
# Text(0, 0.5, 'Phase delay [rad]')

# %%
def generate_sine_wave(amp, freq, fs):
    t = 1
    samples = np.arange(t * fs) / fs
    X_ = amp*np.sin(2 * np.pi * freq * samples)
    X_ = X_.reshape((-1,1))
    return X_

def create_dataset(dataset, look_back):
    dataX = []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
    return np.array(dataX)

# %%
amp = 0.5 # [-]
# freq = 50 # [Hz]
m = 1000000 # original data is at 1000000 Hz
fs = int(m/m_sample) # resampled frequency is m/m_sample
ts = np.arange(0.1 * fs) / fs # create a 0.1 s long time array with a sample equal to sample rate

Gain_pred = []
phase_pred = []
for ifreq in range(len(FDF_freq[0,:])):
    freq = FDF_freq[0,ifreq]
    Xsin = generate_sine_wave(amp, freq, fs)
    XXsin = create_dataset(Xsin,look_back)
    YY_sin = model.predict(XXsin)
    Gain_pred.append(np.max(YY_sin)/np.max(Xsin))
    correlation = signal.correlate(Xsin,YY_sin, mode='full')
    lags = signal.correlation_lags(Xsin.size, YY_sin.size, mode='full')
    lag = lags[np.argmax(correlation)]
    phase_pred.append(lag/fs*np.pi*2.0*freq%(np.pi*2.0))
# Out:
# 3104/3104 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 3104/3104 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 3104/3104 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 3104/3104 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 3104/3104 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step
# 3104/3104 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 3104/3104 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step

# %% [markdown]
# We compare the flame describing function obtained from our neural network with the one obtained from CFD.

# %%
# %matplotlib inline
fig = plt.figure()
ax = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

for i in range(1):
    ax.plot(FDF_freq[i,:],Gain_pred)
    ax.plot(FDF_freq[i,:],FDF_Gain[i,:],'x')
    ax2.plot(FDF_freq[i,:],np.unwrap(-np.array(phase_pred))+np.pi)
    ax2.plot(FDF_freq[i,:],FDF_phase[i,:],'x')

ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel('Gain [-]')
ax2.set_xlabel('Frequency [Hz]')
ax2.set_ylabel('Phase delay [rad]')
# Out:
# Text(0, 0.5, 'Phase delay [rad]')
